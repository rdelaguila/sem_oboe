# %%
import joblib

df = joblib.load('./data/corpus_raw/bbc/bbc_processed.pkl')

# %%
df.head()

# %%
df.iloc[10,4]

# %%
df.head()
# Out:
#                                                 news      type  \
# 0  China had role in Yukos split-up\n \n China le...  business
# 1  Oil rebounds from weather effect\n \n Oil pric...  business
# 2  Indonesia 'declines debt freeze'\n \n Indonesi...  business
# 3  $1m payoff for former Shell boss\n \n Shell is...  business
# 4  US bank in $515m SEC settlement\n \n Five Bank...  business
#
#                                           text_coref  \
# 0  China had role in Yukos split-up\n \n China le...
# 1  Oil rebounds from weather effect\n \n Oil pric...
# 2  Indonesia 'declines debt freeze'\n \n Indonesi...
# 3  $1m payoff for former Shell boss\n \n Shell is...
# 4  US bank in $515m SEC settlement\n \n Five Bank...
#
#                                           text_clean  \
# 0  china had role in yukos splitup\n \n china len...
# 1  oil rebounds from weather effect\n \n oil pric...
# 2  indonesia declines debt freeze\n \n indonesia ...
# ...

# %%
df.iloc[10,4]
# Out:
# {'tsunami': {'URI': 'http://dbpedia.org/resource/2004_Indian_Ocean_earthquake_and_tsunami',
#   'types': 'Wikidata:Q1656682,DUL:Event,Schema:Event,DBpedia:NaturalEvent,DBpedia:Event,DBpedia:Earthquake',
#   'types_normalizados': 'wikidata q1656682,dul event schema event dbpedia naturalevent dbpedia event dbpedia earthquake'},
#  'service sector': {'URI': 'http://dbpedia.org/resource/Tertiary_sector_of_the_economy',
#   'types': [],
#   'types_normalizados': []},
#  'city': {'URI': 'http://dbpedia.org/resource/City',
#   'types': [],
#   'types_normalizados': []},
#  'gross domestic product': {'URI': 'http://dbpedia.org/resource/Gross_domestic_product',
#   'types': [],
#   'types_normalizados': []},
#  'gdp': {'URI': 'http://dbpedia.org/resource/Gross_domestic_product',
#   'types': [],
#   'types_normalizados': []},
#  'drag': {'URI': 'http://dbpedia.org/resource/Drag_queen',
#   'types': [],
#   'types_normalizados': []},
# ...
