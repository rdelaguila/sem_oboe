# %%
import joblib
import pandas as pd
import pickle

# %%
## cargamos data procesado

df = joblib.load('./data/processed/amazon/amazon_processed_semantic.pkl')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 ## cargamos data procesado
# ----> 3 df = joblib.load('./data/processed/amazon/amazon_processed_semantic.pkl')
#
# File ~/repos_personales/semoboe-articulo/.venv/lib/python3.11/site-packages/joblib/numpy_pickle.py:650, in load(filename, mmap_mode)
#     648         obj = _unpickle(fobj)
#     649 else:
# --> 650     with open(filename, 'rb') as f:
#     651         with _read_fileobject(f, filename, mmap_mode) as fobj:
#     652             if isinstance(fobj, str):
#     653                 # if the returned file object is a string, this means we
#     654                 # try to load a pickle file generated with an version of
#     655                 # Joblib so we load it with joblib compatibility function.
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df = joblib.load('./data/lda_eval/reuters_activities/lda_model')
#
# File ~/repos_personales/semoboe-articulo/.venv/lib/python3.11/site-packages/joblib/numpy_pickle.py:650, in load(filename, mmap_mode)
#     648         obj = _unpickle(fobj)
#     649 else:
# --> 650     with open(filename, 'rb') as f:
#     651         with _read_fileobject(f, filename, mmap_mode) as fobj:
#     652             if isinstance(fobj, str):
#     653                 # if the returned file object is a string, this means we
#     654                 # try to load a pickle file generated with an version of
#     655                 # Joblib so we load it with joblib compatibility function.
#
# FileNotFoundError: [Errno 2] No such file or directory: './data/lda_eval/reuters_activities/lda_model'

# %%
# !pwd
# Out:
# /Users/Raul/repos_personales/semoboe-articulo/data/corpus_raw/amazon
